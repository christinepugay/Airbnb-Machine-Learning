# %% [markdown]
# # Airbnb Text Mining

# %%
import pandas as pd
import numpy as np
import spacy
from string import punctuation

# %% [markdown]
# ## Slice all text columns from the listing.csv file.

# %%
listings = pd.read_csv('listings_cleaned_20230303.csv')

# %%
text_features= listings[['id','name','description','neighborhood_overview','host_about','price']]
text_features
# Out:
#                id                                               name  \
# 0        183319.0                  Panoramic Ocean View Venice Beach
# 1         51307.0  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 2        184314.0                    Boho Chic Flat..Steps to Beach!
# 3         51498.0  Guest House With Its Own Entrance/Exit and Hot...
# 4           109.0   Amazing bright elegant condo park front UPGRADED
# ...           ...                                                ...
# 45209  26665862.0                           Queen Bed, Foam Mattress
# 45210  26898605.0   SANITIZED Modern Zen Getaway | Relax & Replenish
# 45211  26895703.0        Simple, Clean, Modern One Bedroom Apartment
# 45212  26954426.0                                     Oak Park House
# 45213  27901174.0   SANITIZED Forest Zen| KingBD | Updated & Stylish
#
#                                              description  \
# 0      Craftsmen style penthouse with ocean view from...
# 1      PRIVATE GUEST HOUSE The space Private, Guest h...
# 2      Bright, airy, quiet 1 bdr located just steps f...
# 3      Fully self-contained, separate structure, with...
# 4       Unit upgraded with new bamboo flooring, brand...
# ...                                                  ...
# 45209  Queen bed with a soft foam mattress in a priva...
# 45210  Are you more than ready for a Local Getaway? N...
# 45211  Welcome to Anaheim!  This one bedroom suite ha...
# 45212  Good location, new carpet, kitchen and floorin...
# 45213  Now is a great time for meaningful travel with...
#
#                                    neighborhood_overview  \
# 0      About as close to the beach as you can live in...
# 1      Local LA  Community , shops and restaurants in...
# 2      You are in one of the beach locations in Los A...
# 3      We are close to Venice without the hassle of n...
# 4                                                    NaN
# ...                                                  ...
# 45209  -Near Fairview Regional Park with hiking, biki...
# 45210  We are conveniently located just minutes from ...
# 45211  We are in a safe and happy area.  The street m...
# 45212  Close to Brookside elementary, Medea creek and...
# 45213  We are conveniently located just minutes from ...
#
#                                               host_about  price
# 0      Serious yoga practice.  Been studying for 25 y...  152.0
# 1      male , educated . Healthcare Professional\r\nC...   75.0
# 2      Health-Wellness Professional. Author. Passiona...  125.0
# 3      Easy going hostess!! Enjoy your stay. \n\nI am...  189.0
# 4      Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...  115.0
# ...                                                  ...    ...
# 45209                                                NaN   60.0
# 45210  Hi! My name is Isabella and I am a first gener...  104.0
# 45211  It is nice finding that place where you can ju...  134.0
# 45212                                                NaN  300.0
# 45213  Hi! My name is Isabella and I am a first gener...  105.0
#
# [45214 rows x 6 columns]

# %%
text_features.shape
# Out:
# (45214, 6)

# %%
text_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45214 entries, 0 to 45213
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     45214 non-null  float64
#  1   name                   45212 non-null  object
#  2   description            44403 non-null  object
#  3   neighborhood_overview  26565 non-null  object
#  4   host_about             26256 non-null  object
#  5   price                  45214 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 2.1+ MB

# %%
text_features.isnull().sum()
# Out:
# id                           0
# name                         2
# description                811
# neighborhood_overview    18649
# host_about               18958
# price                        0
# dtype: int64

# %%
text_features.head(10)
# Out:
#          id                                               name  \
# 0  183319.0                  Panoramic Ocean View Venice Beach
# 1   51307.0  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 2  184314.0                    Boho Chic Flat..Steps to Beach!
# 3   51498.0  Guest House With Its Own Entrance/Exit and Hot...
# 4     109.0   Amazing bright elegant condo park front UPGRADED
# 5  185536.0       Lovely Private rm in Home to FEMALE Red Room
# 6    2708.0  Runyon Canyon | Beau Furn Mirror Mini-Suite Fi...
# 7   51546.0                  Cool Pad Under the Hollywood Sign
# 8  185557.0    Private Room in Home to FEMALE, pls Purple Room
# 9    2732.0                              Zen Life at the Beach
#
#                                          description  \
# 0  Craftsmen style penthouse with ocean view from...
# 1  PRIVATE GUEST HOUSE The space Private, Guest h...
# 2  Bright, airy, quiet 1 bdr located just steps f...
# 3  Fully self-contained, separate structure, with...
# 4   Unit upgraded with new bamboo flooring, brand...
# 5  The space Hello,, Ladies!!! I offer you Privac...
# 6  Run Runyon Canyon, Our Gym & Sauna Open  Beaut...
# 7   Please note, after January 2, 2020 we can onl...
# 8  The space Hello, Ladies! I am a female homeown...
# 9  An oasis of tranquility awaits you. The space ...
#
#                                neighborhood_overview  \
# 0  About as close to the beach as you can live in...
# 1  Local LA  Community , shops and restaurants in...
# 2  You are in one of the beach locations in Los A...
# 3  We are close to Venice without the hassle of n...
# 4                                                NaN
# 5                                                NaN
# 6  Walk and run to Runyon Canyon, it is open! We ...
# 7  Beachwood Canyon is peaceful, natural, and lov...
# 8  Quiet environment..Drama- Free, Privacy and Re...
# 9  This is the best part of Santa Monica. Quiet, ...
#
#                                           host_about  price
# 0  Serious yoga practice.  Been studying for 25 y...  152.0
# 1  male , educated . Healthcare Professional\r\nC...   75.0
# 2  Health-Wellness Professional. Author. Passiona...  125.0
# 3  Easy going hostess!! Enjoy your stay. \n\nI am...  189.0
# 4  Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...  115.0
# 5                       Laura..seamstress in L.A. Ca   85.0
# 6  Writer.\r\nLiterary Manager.\r\nPhotographer.\...   93.0
# 7  I'm a pretty happy person, I love music, garde...  100.0
# 8                       Laura..seamstress in L.A. Ca   85.0
# 9  I have been teaching yoga and meditation for 3...  179.0

# %%
#save text columns to csv file
text_features.to_csv('text_features.csv')

# %% [markdown]
# ## Understanding text columns and dealing with null values

# %%
text_columns= pd.read_csv('text_features.csv')
text_columns.head()
# Out:
#          id                                               name  \
# 0  183319.0                  Panoramic Ocean View Venice Beach
# 1   51307.0  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 2  184314.0                    Boho Chic Flat..Steps to Beach!
# 3   51498.0  Guest House With Its Own Entrance/Exit and Hot...
# 4     109.0   Amazing bright elegant condo park front UPGRADED
#
#                                          description  \
# 0  Craftsmen style penthouse with ocean view from...
# 1  PRIVATE GUEST HOUSE The space Private, Guest h...
# 2  Bright, airy, quiet 1 bdr located just steps f...
# 3  Fully self-contained, separate structure, with...
# 4   Unit upgraded with new bamboo flooring, brand...
#
#                                neighborhood_overview  \
# 0  About as close to the beach as you can live in...
# 1  Local LA  Community , shops and restaurants in...
# 2  You are in one of the beach locations in Los A...
# 3  We are close to Venice without the hassle of n...
# 4                                                NaN
#
#                                           host_about  price
# 0  Serious yoga practice.  Been studying for 25 y...  152.0
# 1  male , educated . Healthcare Professional\r\nC...   75.0
# 2  Health-Wellness Professional. Author. Passiona...  125.0
# 3  Easy going hostess!! Enjoy your stay. \n\nI am...  189.0
# 4  Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...  115.0

# %%
text_columns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45214 entries, 0 to 45213
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     45214 non-null  float64
#  1   name                   45212 non-null  object
#  2   description            44403 non-null  object
#  3   neighborhood_overview  26565 non-null  object
#  4   host_about             26256 non-null  object
#  5   price                  45214 non-null  float64
# dtypes: float64(2), object(4)
# memory usage: 2.1+ MB

# %%
text_columns.isnull().sum()
# Out:
# id                           0
# name                         2
# description                811
# neighborhood_overview    18649
# host_about               18958
# price                        0
# dtype: int64

# %%
## I replaced all null values with 'NULL'
text_columns= text_columns.fillna('NULL')

# %%
text_columns.isnull().sum()
# Out:
# Unnamed: 0               0
# id                       0
# name                     0
# description              0
# neighborhood_overview    0
# host_about               0
# price                    0
# dtype: int64

# %% [markdown]
# ## Count tokens and sentences using Spacy
# Note: This part of the code counts tokens and sentences in each text records
#
# Each count is recorded to dataset as:
#
# (column name)_TC for Token Count
# (column name)_SC for Sentence Count

# %%
nlp = spacy.load("en_core_web_sm")

def countToken(text):
  doc = nlp(text) # Create a Doc object
  tokens = [token.text for token in doc]
  return len(tokens)

def countSentence(text):
  doc = nlp(text) # Create a Doc object
  sentences = [sentence for sentence in doc.sents]
  #sentences = list(doc.sents) #alternative
  return len(sentences)

# %%
text_columns['name_TC']= text_columns['name'].map(countToken)
text_columns['name_SC']= text_columns['name'].map(countSentence)

# %%
text_columns['description_TC']= text_columns['description'].map(countToken)
text_columns['description_SC']= text_columns['description'].map(countSentence)

# %%
text_columns['neighborhood_overview_TC']= text_columns['neighborhood_overview'].map(countToken)
text_columns['neighborhood_overview_SC']= text_columns['neighborhood_overview'].map(countSentence)

# %%
text_columns['host_about_TC']= text_columns['host_about'].map(countToken)
text_columns['host_about_SC']= text_columns['host_about'].map(countSentence)

# %%
text_columns.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  183319.0                  Panoramic Ocean View Venice Beach
# 1           1   51307.0  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 2           2  184314.0                    Boho Chic Flat..Steps to Beach!
# 3           3   51498.0  Guest House With Its Own Entrance/Exit and Hot...
# 4           4     109.0   Amazing bright elegant condo park front UPGRADED
#
#                                          description  \
# 0  Craftsmen style penthouse with ocean view from...
# 1  PRIVATE GUEST HOUSE The space Private, Guest h...
# 2  Bright, airy, quiet 1 bdr located just steps f...
# 3  Fully self-contained, separate structure, with...
# 4   Unit upgraded with new bamboo flooring, brand...
#
#                                neighborhood_overview  \
# 0  About as close to the beach as you can live in...
# 1  Local LA  Community , shops and restaurants in...
# 2  You are in one of the beach locations in Los A...
# 3  We are close to Venice without the hassle of n...
# 4                                               NULL
#
#                                           host_about  price  name_TC  name_SC  \
# 0  Serious yoga practice.  Been studying for 25 y...  152.0        5        1
# 1  male , educated . Healthcare Professional\r\nC...   75.0       10        2
# 2  Health-Wellness Professional. Author. Passiona...  125.0        8        1
# 3  Easy going hostess!! Enjoy your stay. \n\nI am...  189.0       11        1
# 4  Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...  115.0        7        1
#
#    description_TC  description_SC  neighborhood_overview_TC  \
# 0             163              13                        19
# 1             203              17                        24
# 2             185              15                        51
# 3             195               9                        13
# 4             178              11                         1
#
#    neighborhood_overview_SC  host_about_TC  host_about_SC
# 0                         1             63              5
# 1                         2             65              4
# 2                         3             14              3
# 3                         1            102              5
# 4                         1            301             10

# %% [markdown]
# ## Preprocessing

# %%
#Peprocessing
import spacy
nlp = spacy.load("en_core_web_sm")
import re
from string import punctuation
stop_words = nlp.Defaults.stop_words

# %% [markdown]
# For Preprocessing, these were were done:
#
# transform all text into lower case
# replace all HTML tags
# remove all hyperlinks
# replace non-alphanumerics with space
# remove single characters
# replace multiple spaces with one space
# remove any repeated characters like hellooo

# %%
def preprocess_text(text):
  text = text.lower() # Lowercase text
  text = re.sub("<[^>]*>", " ", text) # Replace HTML tags with space - this needs to be before removing special characters
  text = re.sub(r"https?://\S+", "", text) # Remove hyperlinks
  text = re.sub(r"\W"," ",text) #replace non-alphanumerics with space
  text = re.sub(r"\s+[a-z]\s+"," ", text) #remove single character
  text = re.sub(r"\s+"," ",text)  #replace multiple spaces with one space
  text = re.sub(r'(.)\1{3,}',r'\1', text) # Remove repeated characters like hellooo

  # text = re.sub(r"[!#$+-@\']/g","", text) # remove special characters and punctuations
  # text = re.sub(f"[{re.escape(punctuation)}]", "", text)  # Remove punctuation
  # text = re.sub(r"[^A-Za-z0-9\s]+", " ", text) # Replace special characters and punctuation with space
  # text = " ".join(text.split())  # Remove extra spaces, tabs, and new lines

  # In regular expressions, \b anchors the regex at a word boundary or the position between a word and a non-word character, or vice versa.
  # text = re.sub(r"\b\d+\b","", text) # remove digits

  text = remove_stopwords(text)
  text = lemmatize(text)
  return text

# Remove stop words using spaCy
def remove_stopwords(text):
    text_tokens = nlp.tokenizer(text)
    #print (type(text_tokens))
    tokens_without_sw = [t.text for t in text_tokens if not t.text in stop_words]
    #print (type(tokens_without_sw))
    text = " ".join(tokens_without_sw)
    return text

# %%
text_columns['cleaned_name']= text_columns['name'].map(preprocess_text)

# %%
text_columns['cleaned_description']= text_columns['description'].map(preprocess_text)

# %%
text_columns['cleaned_neighborhood_overview']= text_columns['neighborhood_overview'].map(preprocess_text)

# %%
text_columns['cleaned_host_about']= text_columns['host_about'].map(preprocess_text)

# %%
text_columns.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  183319.0                  Panoramic Ocean View Venice Beach
# 1           1   51307.0  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 2           2  184314.0                    Boho Chic Flat..Steps to Beach!
# 3           3   51498.0  Guest House With Its Own Entrance/Exit and Hot...
# 4           4     109.0   Amazing bright elegant condo park front UPGRADED
#
#                                          description  \
# 0  Craftsmen style penthouse with ocean view from...
# 1  PRIVATE GUEST HOUSE The space Private, Guest h...
# 2  Bright, airy, quiet 1 bdr located just steps f...
# 3  Fully self-contained, separate structure, with...
# 4   Unit upgraded with new bamboo flooring, brand...
#
#                                neighborhood_overview  \
# 0  About as close to the beach as you can live in...
# 1  Local LA  Community , shops and restaurants in...
# 2  You are in one of the beach locations in Los A...
# 3  We are close to Venice without the hassle of n...
# 4                                               NULL
#
#                                           host_about  price  name_TC  name_SC  \
# 0  Serious yoga practice.  Been studying for 25 y...  152.0        5        1
# 1  male , educated . Healthcare Professional\r\nC...   75.0       10        2
# 2  Health-Wellness Professional. Author. Passiona...  125.0        8        1
# 3  Easy going hostess!! Enjoy your stay. \n\nI am...  189.0       11        1
# 4  Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...  115.0        7        1
#
#    description_TC  description_SC  neighborhood_overview_TC  \
# 0             163              13                        19
# 1             203              17                        24
# 2             185              15                        51
# 3             195               9                        13
# 4             178              11                         1
#
#    neighborhood_overview_SC  host_about_TC  host_about_SC  \
# 0                         1             63              5
# 1                         2             65              4
# 2                         3             14              3
# 3                         1            102              5
# 4                         1            301             10
#
#                                     cleaned_name  \
# 0              panoramic ocean view venice beach
# 1  spanish bungalow guest house la 30 plus night
# 2                      boho chic flat step beach
# 3              guest house entrance exit hot tub
# 4      amazing bright elegant condo park upgrade
#
#                                  cleaned_description  \
# 0  craftsman style penthouse ocean view room park...
# 1  private guest house space private guest house ...
# 2  bright airy quiet 1 bdr locate step seclude cl...
# 3  fully self contain separate structure entrance...
# 4     unit upgrade new bamboo floor brand new ult...
#
#                        cleaned_neighborhood_overview  \
# 0                  close beach live venice boardwalk
# 1  local la community shop restaurant walk distan...
# 2  beach location los angeles peninsula marina de...
# 3                  close venice hassle parking space
# 4                                               null
#
#                                   cleaned_host_about
# 0  yoga practice study 25 year spend month thaila...
# 1  male educate healthcare professional cycle run...
# 2  health wellness professional author passionate...
# 3  easy go hostess enjoy stay experienced travele...
# 4  paolo privitera ceo evensi paolo mit mba phone...

# %%
# saves df into csv for personal record
text_columns.to_csv('cleaned_text_features')

# %%
# Recounts tokens and sentences for comparison
text_columns['name_TC_afterProcess']= text_columns['cleaned_name'].map(countToken)
text_columns['name_SC_afterProcess']= text_columns['cleaned_name'].map(countSentence)

# %%
#Compares intial count to afterProcess token and sentence count
text_columns[['name_TC', 'name_SC','name_TC_afterProcess','name_SC_afterProcess']]
# Out:
#        name_TC  name_SC  name_TC_afterProcess  name_SC_afterProcess
# 0            5        1                     5                     1
# 1           10        2                     8                     1
# 2            8        1                     5                     1
# 3           11        1                     6                     1
# 4            7        1                     6                     1
# ...        ...      ...                   ...                   ...
# 45209        5        1                     4                     1
# 45210        8        1                     6                     1
# 45211        8        1                     5                     1
# 45212        3        1                     3                     1
# 45213        8        1                     6                     1
#
# [45214 rows x 4 columns]

# %%
text_columns['description_TC_afterProcess']= text_columns['cleaned_description'].map(countToken)
text_columns['description_SC_afterProcess']= text_columns['cleaned_description'].map(countSentence)

# %%
text_columns['neighborhood_overview_TC_afterProcess']= text_columns['cleaned_neighborhood_overview'].map(countToken)
text_columns['neighborhood_overview_SC_afterProcess']= text_columns['cleaned_neighborhood_overview'].map(countSentence)

# %%
text_columns['host_about_TC_afterProcess']= text_columns['cleaned_host_about'].map(countToken)
text_columns['host_about_SC_afterProcess']= text_columns['cleaned_host_about'].map(countSentence)

# %%
text_columns.head()
# Out:
#    Unnamed: 0        id                                               name  \
# 0           0  183319.0                  Panoramic Ocean View Venice Beach
# 1           1   51307.0  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 2           2  184314.0                    Boho Chic Flat..Steps to Beach!
# 3           3   51498.0  Guest House With Its Own Entrance/Exit and Hot...
# 4           4     109.0   Amazing bright elegant condo park front UPGRADED
#
#                                          description  \
# 0  Craftsmen style penthouse with ocean view from...
# 1  PRIVATE GUEST HOUSE The space Private, Guest h...
# 2  Bright, airy, quiet 1 bdr located just steps f...
# 3  Fully self-contained, separate structure, with...
# 4   Unit upgraded with new bamboo flooring, brand...
#
#                                neighborhood_overview  \
# 0  About as close to the beach as you can live in...
# 1  Local LA  Community , shops and restaurants in...
# 2  You are in one of the beach locations in Los A...
# 3  We are close to Venice without the hassle of n...
# 4                                               NULL
#
#                                           host_about  price  name_TC  name_SC  \
# 0  Serious yoga practice.  Been studying for 25 y...  152.0        5        1
# 1  male , educated . Healthcare Professional\r\nC...   75.0       10        2
# 2  Health-Wellness Professional. Author. Passiona...  125.0        8        1
# 3  Easy going hostess!! Enjoy your stay. \n\nI am...  189.0       11        1
# 4  Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...  115.0        7        1
#
#    description_TC  ...                      cleaned_neighborhood_overview  \
# 0             163  ...                  close beach live venice boardwalk
# 1             203  ...  local la community shop restaurant walk distan...
# 2             185  ...  beach location los angeles peninsula marina de...
# 3             195  ...                  close venice hassle parking space
# 4             178  ...                                               null
#
#                                   cleaned_host_about  name_TC_afterProcess  \
# 0  yoga practice study 25 year spend month thaila...                     5
# 1  male educate healthcare professional cycle run...                     8
# 2  health wellness professional author passionate...                     5
# 3  easy go hostess enjoy stay experienced travele...                     6
# 4  paolo privitera ceo evensi paolo mit mba phone...                     6
#
#    name_SC_afterProcess  description_TC_afterProcess  \
# 0                     1                           93
# 1                     1                          109
# 2                     1                          108
# 3                     1                           91
# 4                     1                          119
#
#   description_SC_afterProcess neighborhood_overview_TC_afterProcess  \
# 0                           1                                     5
# 1                           2                                    15
# 2                           1                                    22
# 3                           1                                     5
# 4                           1                                     1
#
#   neighborhood_overview_SC_afterProcess host_about_TC_afterProcess  \
# 0                                     1                         25
# 1                                     1                         37
# 2                                     1                          8
# 3                                     1                         48
# 4                                     1                        143
#
#    host_about_SC_afterProcess
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
#
# [5 rows x 27 columns]

# %%
# saves df into csv for personal record
text_columns.to_csv('my_cleaned_text_features2.csv')

# %%
cleaned_text_features= pd.read_csv('my_cleaned_text_features2.csv')

# %%
cleaned_text_features.head()
# Out:
#          id                                               name  \
# 0  183319.0                  Panoramic Ocean View Venice Beach
# 1   51307.0  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 2  184314.0                    Boho Chic Flat..Steps to Beach!
# 3   51498.0  Guest House With Its Own Entrance/Exit and Hot...
# 4     109.0   Amazing bright elegant condo park front UPGRADED
#
#                                          description  \
# 0  Craftsmen style penthouse with ocean view from...
# 1  PRIVATE GUEST HOUSE The space Private, Guest h...
# 2  Bright, airy, quiet 1 bdr located just steps f...
# 3  Fully self-contained, separate structure, with...
# 4   Unit upgraded with new bamboo flooring, brand...
#
#                                neighborhood_overview  \
# 0  About as close to the beach as you can live in...
# 1  Local LA  Community , shops and restaurants in...
# 2  You are in one of the beach locations in Los A...
# 3  We are close to Venice without the hassle of n...
# 4                                                NaN
#
#                                           host_about  price  name_TC  name_SC  \
# 0  Serious yoga practice.  Been studying for 25 y...  152.0        5        1
# 1  male , educated . Healthcare Professional\r\nC...   75.0       10        2
# 2  Health-Wellness Professional. Author. Passiona...  125.0        8        1
# 3  Easy going hostess!! Enjoy your stay. \n\nI am...  189.0       11        1
# 4  Paolo Privitera, CEO Evensi\n\nPaolo, MIT MBA ...  115.0        7        1
#
#    description_TC  description_SC  ...  \
# 0             163              13  ...
# 1             203              17  ...
# 2             185              15  ...
# 3             195               9  ...
# 4             178              11  ...
#
#                        cleaned_neighborhood_overview  \
# 0                  close beach live venice boardwalk
# 1  local la community shop restaurant walk distan...
# 2  beach location los angeles peninsula marina de...
# 3                  close venice hassle parking space
# 4                                                NaN
#
#                                   cleaned_host_about  name_TC_afterProcess  \
# 0  yoga practice study 25 year spend month thaila...                     5
# 1  male educate healthcare professional cycle run...                     8
# 2  health wellness professional author passionate...                     5
# 3  easy go hostess enjoy stay experienced travele...                     6
# 4  paolo privitera ceo evensi paolo mit mba phone...                     6
#
#    name_SC_afterProcess description_TC_afterProcess  \
# 0                     1                          93
# 1                     1                         109
# 2                     1                         108
# 3                     1                          91
# 4                     1                         119
#
#   description_SC_afterProcess neighborhood_overview_TC_afterProcess  \
# 0                           1                                     5
# 1                           2                                    15
# 2                           1                                    22
# 3                           1                                     5
# 4                           1                                     1
#
#   neighborhood_overview_SC_afterProcess  host_about_TC_afterProcess  \
# 0                                     1                          25
# 1                                     1                          37
# 2                                     1                           8
# 3                                     1                          48
# 4                                     1                         143
#
#    host_about_SC_afterProcess
# 0                           1
# 1                           1
# 2                           1
# 3                           1
# 4                           1
#
# [5 rows x 26 columns]

# %%
cleaned_text_features.columns
# Out:
# Index(['id', 'name', 'description', 'neighborhood_overview', 'host_about',
#        'price', 'name_TC', 'name_SC', 'description_TC', 'description_SC',
#        'neighborhood_overview_TC', 'neighborhood_overview_SC', 'host_about_TC',
#        'host_about_SC', 'cleaned_name', 'cleaned_description',
#        'cleaned_neighborhood_overview', 'cleaned_host_about',
#        'name_TC_afterProcess', 'name_SC_afterProcess',
#        'description_TC_afterProcess', 'description_SC_afterProcess',
#        'neighborhood_overview_TC_afterProcess',
#        'neighborhood_overview_SC_afterProcess', 'host_about_TC_afterProcess',
#        'host_about_SC_afterProcess'],
#       dtype='object')

# %%
## take processed text columns as its own df and save to a csv (add to OneDrive)

df= cleaned_text_features[['name_TC_afterProcess', 'name_SC_afterProcess',
       'description_TC_afterProcess', 'description_SC_afterProcess']]

df.to_csv('cleaned_text_features_christineVersion.csv')
